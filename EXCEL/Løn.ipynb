# %%
import json
import os
import urllib.request
from pathlib import Path

url = "https://www.krl.dk/sirka/sirkaApi/tableApi"
api_key = os.environ.get(
    "SIRKA_API_KEY",
    "b6caa39c5a6dc520a83ed1624a7bdfdd1935d9fb2bee1d5e2c14dc08ee4ea57ceacca8e9550f5b25ad07b745a612d4b6b5b07bd781baff0908b5891c0beb65c1",
)

out_dir = Path("Data") / "løn_data"
out_dir.mkdir(parents=True, exist_ok=True)


def post_json_excel(*, url: str, payload: dict, timeout: int = 180) -> bytes:
    body = json.dumps(payload).encode("utf-8")
    req = urllib.request.Request(
        url,
        data=body,
        headers={"Content-Type": "application/json"},
        method="POST",
    )
    with urllib.request.urlopen(req, timeout=timeout) as resp:
        return resp.read()


payload_løn_overenskosmt = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [{"y1": "2025", "m1": "02"}],
    "control": ["overenskomst", "kom_reg"],
    "data": ["fuldtid", "lb"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "trs": ["272", "285", "293", "072"],
                "omr": ["1", "8"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Lønniveau",
        "subLimit": 5,
        "modelName": "SIRKA",
        "averageSalary": "fuldtid",
        "timeIncreasing": False,
        "salary": [
            "gl",
            "ct",
            "tck",
            "tcf",
            "tcg",
            "tco",
            "tca",
            "lt",
            "tlk",
            "tlf",
            "tlg",
            "tlr",
            "tla",
            "tle",
            "er",
            "sy",
            "sf",
            "pb",
            "tj",
            "tci",
            "pbb",
            "pbt",
        ],
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content = post_json_excel(url=url, payload=payload_løn_overenskosmt, timeout=180)
out_path = out_dir / "løn_overenskosmt.xlsx"
out_path.write_bytes(content)
print("Wrote:", out_path.resolve())

# %%
payload_løn_stilling = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [{"y1": "2025", "m1": "02"}],
    "control": ["overenskomst", "stilling", "kom_reg"],
    "data": ["fuldtid", "lb"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "trs": ["29602", "29605", "29608", "28901", "06609", "06610", "06608", "06618", "06611", "06620",
                    "06606", "06605", "06617", "28401", "28305", "07801", "05514", "05513", "05519", "05518",
                    "30001", "30101", "11301", "11308", "11304"],
                "omr": ["1", "8"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Lønniveau",
        "subLimit": 5,
        "modelName": "SIRKA",
        "averageSalary": "fuldtid",
        "timeIncreasing": False,
        "salary": [
            "gl",
            "ct",
            "tck",
            "tcf",
            "tcg",
            "tco",
            "tca",
            "lt",
            "tlk",
            "tlf",
            "tlg",
            "tlr",
            "tla",
            "tle",
            "er",
            "sy",
            "sf",
            "pb",
            "tj",
            "tci",
            "pbb",
            "pbt",
        ],
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content = post_json_excel(url=url, payload=payload_løn_stilling, timeout=180)
out_path = out_dir / "løn_stilling.xlsx"
out_path.write_bytes(content)
print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/løn_data/løn_stilling.xlsx

# %%
payload_løn_klassificering = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [{"y1": "2025", "m1": "02"}],
    "control": ["overenskomst", "stilling", "klassificering", "kom_reg"],
    "data": ["fuldtid", "lb"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "trs": ["3002302","3002402", "2960101", "2961001", "2961003", "2960103", "2960102", "2961002"],
                "omr": ["1", "8"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Lønniveau",
        "subLimit": 5,
        "modelName": "SIRKA",
        "averageSalary": "fuldtid",
        "timeIncreasing": False,
        "salary": [
            "gl",
            "ct",
            "tck",
            "tcf",
            "tcg",
            "tco",
            "tca",
            "lt",
            "tlk",
            "tlf",
            "tlg",
            "tlr",
            "tla",
            "tle",
            "er",
            "sy",
            "sf",
            "pb",
            "tj",
            "tci",
            "pbb",
            "pbt",
        ],
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content = post_json_excel(url=url, payload=payload_løn_klassificering, timeout=180)
out_path = out_dir / "løn_klassificering.xlsx"
out_path.write_bytes(content)
print("Wrote:", out_path.resolve())

# %%
payload_løndele_ialt = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [
        {"y1": "2025", "m1": "02"},
        {"y1": "2024", "m1": "02"},
        {"y1": "2023", "m1": "02"},
        {"y1": "2022", "m1": "02"},
        {"y1": "2021", "m1": "02"},
        {"y1": "2020", "m1": "02"},
        {"y1": "2019", "m1": "02"},
        {"y1": "2018", "m1": "02"},
        {"y1": "2017", "m1": "02"},
        {"y1": "2016", "m1": "02"},
        {"y1": "2015", "m1": "02"},
        {"y1": "2014", "m1": "02"},
        {"y1": "2013", "m1": "02"},
        {"y1": "2012", "m1": "02"},
        {"y1": "2011", "m1": "02"},
        {"y1": "2010", "m1": "02"},
    ],
    "control": ["ym"],
    "data": [ "fuldtid","tl", "sy", "ov","ln","lb"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trb":["1", "2"], "afl": ["0", "1"],"omr": ["1", "8"],},
        }
    ],
    "options": {
        "totals": False,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Lønniveau",
        "subLimit": 5,
        "modelName": "SIRKA",
        "averageSalary": "1000",
        "timeIncreasing": True,
        "salary": [
            "gl",
            "ct",
            "tck",
            "tcf",
            "tcg",
            "tco",
            "tca",
            "lt",
            "tlk",
            "tlf",
            "tlg",
            "tlr",
            "tla",
            "tle",
            "er",
            "sy",
            "sf",
            "pb",
            "tj",
            "tci",
            "pbb",
            "pbt",
            "ov",
        ],
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content = post_json_excel(url=url, payload=payload_løndele_ialt, timeout=180)
out_path = out_dir / "løndele_ialt.xlsx"
out_path.write_bytes(content)
print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/løn_data/løndele_ialt.xlsx
