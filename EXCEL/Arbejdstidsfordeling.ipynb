# %%
import json
import os
import urllib.request
from pathlib import Path

url = "https://www.krl.dk/sirka/sirkaApi/tableApi"
api_key = os.environ.get(
    "SIRKA_API_KEY",
    "b6caa39c5a6dc520a83ed1624a7bdfdd1935d9fb2bee1d5e2c14dc08ee4ea57ceacca8e9550f5b25ad07b745a612d4b6b5b07bd781baff0908b5891c0beb65c1",
)


def post_json_excel(*, url: str, payload: dict, timeout: int = 180) -> bytes:
    body = json.dumps(payload).encode("utf-8")
    req = urllib.request.Request(
        url,
        data=body,
        headers={"Content-Type": "application/json"},
        method="POST",
    )
    with urllib.request.urlopen(req, timeout=timeout) as resp:
        return resp.read()


arbejdstidfordeling_akademiker = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["272"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_akademiker, timeout=180)
out_path = out_dir / "akademiker.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/akademiker.xlsx

# %%
arbejdstidfordeling_Sygeplejersker = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["30001", "3002302", "3002402"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_Sygeplejersker, timeout=180)
out_path = out_dir / "sygeplejersker.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/sygeplejersker.xlsx

# %%
arbejdstidfordeling_afdelingslæger = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["11304","11310"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_afdelingslæger, timeout=180)
out_path = out_dir / "afdelingslæger.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/afdelingslæger.xlsx

# %%
arbejdstidfordeling_uddannelseslæger = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["11301","11308"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_uddannelseslæger, timeout=180)
out_path = out_dir / "uddannelseslæger.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/uddannelseslæger.xlsx

# %%
arbejdstidfordeling_ledende_sygeplejersker = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["30101"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_ledende_sygeplejersker, timeout=180)
out_path = out_dir / "ledende_sygeplejersker.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/ledende_sygeplejersker.xlsx

# %%
arbejdstidfordeling_socialpædagoger = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["07801"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_socialpædagoger, timeout=180)
out_path = out_dir / "socialpædagoger.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/socialpædagoger.xlsx

# %%
arbejdstidfordeling_SOSU = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["28305"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_SOSU, timeout=180)
out_path = out_dir / "sosu.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/sosu.xlsx

# %%
arbejdstidfordeling_sundhedsadministrativt = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["05503","05513","05514","05518"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_sundhedsadministrativt, timeout=180)
out_path = out_dir / "sundhedsadministrativt_personale.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/sundhedsadministrativt_personale.xlsx

# %%
arbejdstidfordeling_sygehusportører = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["07201"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_sygehusportører, timeout=180)
out_path = out_dir / "sygehusportører.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/sygehusportører.xlsx

# %%
arbejdstidfordeling_omsorgs_og_pædagog = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["293"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_omsorgs_og_pædagog, timeout=180)
out_path = out_dir / "omsorgs_og_pædagog.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/omsorgs_og_pædagog.xlsx

# %%
arbejdstidfordeling_Ren_Hus = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["28401","28901"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_Ren_Hus, timeout=180)
out_path = out_dir / "rengøring_husassistenter.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/rengøring_husassistenter.xlsx

# %%
arbejdstidfordeling_Erhvervsudd_service = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["285"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_Erhvervsudd_service, timeout=180)
out_path = out_dir / "erhvervsudd_service.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/erhvervsudd_service.xlsx

# %%
arbejdstidfordeling_Fysioterapeuter = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["29605","2960102","2961002"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_Fysioterapeuter, timeout=180)
out_path = out_dir / "fysioterapeuter.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/fysioterapeuter.xlsx

# %%
arbejdstidfordeling_Ergoterapeuter = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["29602", "2960101", "2961001"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_Ergoterapeuter, timeout=180)
out_path = out_dir / "ergoterapeuter.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/ergoterapeuter.xlsx

# %%
arbejdstidfordeling_Jordemødre = {
    "apiKey": api_key,
    "table": "Arbejdstid ugeplan",
    "time": [{"y1": "2023"}],
    "control": ["tidspunkt"],
    "data": [
        "mandag",
        "tirsdag",
        "onsdag",
        "torsdag",
        "fredag",
        "lordag",
        "sondag",
        "heluge",
    ],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {"trs": ["29608","2960103","2961003"]},
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Tidsfordeling",
        "subLimit": 5,
        "modelName": "Arbejdstidsdata",
        "kom": "002",
        "timeIncreasing": False,
        "hideTimeline": 1,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "arbejdstidfordeling"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=arbejdstidfordeling_Jordemødre, timeout=180)
out_path = out_dir / "jordemødre.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/arbejdstidfordeling/jordemødre.xlsx
