# %%
import json
import os
import urllib.request
from pathlib import Path

url = "https://www.krl.dk/sirka/sirkaApi/tableApi"
api_key = os.environ.get(
    "SIRKA_API_KEY",
    "b6caa39c5a6dc520a83ed1624a7bdfdd1935d9fb2bee1d5e2c14dc08ee4ea57ceacca8e9550f5b25ad07b745a612d4b6b5b07bd781baff0908b5891c0beb65c1",
)

out_dir = Path("Data") / "Fravær_data"
out_dir.mkdir(parents=True, exist_ok=True)


def post_json_excel(*, url: str, payload: dict, timeout: int = 180) -> bytes:
    body = json.dumps(payload).encode("utf-8")
    req = urllib.request.Request(
        url,
        data=body,
        headers={"Content-Type": "application/json"},
        method="POST",
    )
    with urllib.request.urlopen(req, timeout=timeout) as resp:
        return resp.read()

payload_ialt_syg = {
    "apiKey": api_key,
  "table": "Fravær Årsstatistik",
  "time": [
    {"y1": "2024"},
    {"y1": "2023"},
    {"y1": "2022"},
    {"y1": "2021"},
    {"y1": "2020"},
    {"y1": "2019"},
    {"y1": "2018"},
    {"y1": "2017"},
    {"y1": "2016"},
    {"y1": "2015"}
  ],
  "control": [],
  "data": [
    "f_fuld",
    "f_dag",
    "f_dp"
  ],
  "selection": [
    {
      "name": "Udvalgte population",
      "filters": {
        "trb": [
          "1",
          "2",
          "3",
          "4",
          "5"
        ],
        "omr": [
          "1",
          "8"
        ],
        "lif": [
          "10101",
          "10103",
          "10191",
          "10102"
        ]
      }
    }
  ],
  "options": {
    "totals": True,
    "outputFormat": "excel",
    "actions": [],
    "tableName": "Fravær - Årligt",
    "subLimit": 5,
    "modelName": "Fravær",
    "timeIncreasing": True,
    "hideTimeline": 1
  },
  "dimension": {
    "viewportHeight": 812,
    "viewportWidth": 1440,
    "xsMaxWidth": 768,
    "smMaxWidth": 992,
    "mdMaxWidth": 1200,
    "CONSTANTS": {
      "XS": 0,
      "SM": 1,
      "MD": 2,
      "LG": 3,
      "MAIL": 4
    }
  }
}

# %%
content = post_json_excel(url=url, payload=payload_ialt_syg, timeout=180)
out_path = out_dir / "Fravær_ialt.xlsx"
out_path.write_bytes(content)
print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/Fravær_data/Fravær_ialt.xlsx

# %%
payload_overenskomst_syg = {
    "apiKey": api_key,
  "table": "Fravær Årsstatistik",
  "time": [
    {"y1": "2024"}
  ],
  "control": ["overenskomst"],
  "data": [
    "f_fuld",
    "f_dag",
    "f_dp"
  ],
  "selection": [
    {
      "name": "Udvalgte population",
      "filters": {
          "trs_aar_frav": ["272", "285", "293", "072"],
        "trb": [
          "1",
          "2",
          "3",
          "4",
          "5"
        ],
        "omr": [
          "1",
          "8"
        ],
        "lif": [
          "10101",
          "10103",
          "10191",
          "10102"
        ]
      }
    }
  ],
  "options": {
    "totals": False,
    "outputFormat": "excel",
    "actions": [],
    "tableName": "Fravær - Årligt",
    "subLimit": 5,
    "modelName": "Fravær",
    "timeIncreasing": True,
    "hideTimeline": 1
  },
  "dimension": {
    "viewportHeight": 812,
    "viewportWidth": 1440,
    "xsMaxWidth": 768,
    "smMaxWidth": 992,
    "mdMaxWidth": 1200,
    "CONSTANTS": {
      "XS": 0,
      "SM": 1,
      "MD": 2,
      "LG": 3,
      "MAIL": 4
    }
  }
}

# %%
content = post_json_excel(url=url, payload=payload_overenskomst_syg, timeout=180)
out_path = out_dir / "Fravær_overenskomst.xlsx"
out_path.write_bytes(content)
print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/Fravær_data/Fravær_overenskomst.xlsx

# %%
payload_stilling_syg = {
    "apiKey": api_key,
  "table": "Fravær Årsstatistik",
  "time": [
    {"y1": "2024"}
  ],
  "control": ["overenskomst", "stilling"],
  "data": [
    "f_fuld",
    "f_dag",
    "f_dp"
  ],
  "selection": [
    {
      "name": "Udvalgte population",
      "filters": {
          "trs_aar_frav": ["29602", "29605", "29608", "28901", "06609", "06610", "06608", "06618", "06611", "06620",
                    "06606", "06605", "06617", "28401", "28305", "07801", "05514", "05513", "05519", "05518",
                    "30001", "30101", "11301", "11308", "11304"],
        "trb": [
          "1",
          "2",
          "3",
          "4",
          "5"
        ],
        "omr": [
          "1",
          "8"
        ],
        "lif": [
          "10101",
          "10103",
          "10191",
          "10102"
        ]
      }
    }
  ],
  "options": {
    "totals": False,
    "outputFormat": "excel",
    "actions": [],
    "tableName": "Fravær - Årligt",
    "subLimit": 5,
    "modelName": "Fravær",
    "timeIncreasing": True,
    "hideTimeline": 1
  },
  "dimension": {
    "viewportHeight": 812,
    "viewportWidth": 1440,
    "xsMaxWidth": 768,
    "smMaxWidth": 992,
    "mdMaxWidth": 1200,
    "CONSTANTS": {
      "XS": 0,
      "SM": 1,
      "MD": 2,
      "LG": 3,
      "MAIL": 4
    }
  }
}

# %%
content = post_json_excel(url=url, payload=payload_stilling_syg, timeout=180)
out_path = out_dir / "Fravær_stilling.xlsx"
out_path.write_bytes(content)
print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/Fravær_data/Fravær_stilling.xlsx

# %%
payload_klassificering_syg = {
    "apiKey": api_key,
  "table": "Fravær Årsstatistik",
  "time": [
    {"y1": "2024"}
  ],
  "control": ["overenskomst", "stilling", "klassificering"],
  "data": [
    "f_fuld",
    "f_dag",
    "f_dp"
  ],
  "selection": [
    {
      "name": "Udvalgte population",
      "filters": {
          "trs_aar_frav": ["3002302","3002402", "2960101", "2961001", "2961003", "2960103", "2960102", "2961002"],
        "trb": [
          "1",
          "2",
          "3",
          "4",
          "5"
        ],
        "omr": [
          "1",
          "8"
        ],
        "lif": [
          "10101",
          "10103",
          "10191",
          "10102"
        ]
      }
    }
  ],
  "options": {
    "totals": False,
    "outputFormat": "excel",
    "actions": [],
    "tableName": "Fravær - Årligt",
    "subLimit": 5,
    "modelName": "Fravær",
    "timeIncreasing": True,
    "hideTimeline": 1
  },
  "dimension": {
    "viewportHeight": 812,
    "viewportWidth": 1440,
    "xsMaxWidth": 768,
    "smMaxWidth": 992,
    "mdMaxWidth": 1200,
    "CONSTANTS": {
      "XS": 0,
      "SM": 1,
      "MD": 2,
      "LG": 3,
      "MAIL": 4
    }
  }
}

# %%
content = post_json_excel(url=url, payload=payload_klassificering_syg, timeout=180)
out_path = out_dir / "Fravær_klassificering.xlsx"
out_path.write_bytes(content)
print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/Fravær_data/Fravær_klassificering.xlsx
