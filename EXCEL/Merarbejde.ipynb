# %%
import json
import os
import urllib.request
from pathlib import Path

url = "https://www.krl.dk/sirka/sirkaApi/tableApi"
api_key = os.environ.get(
    "SIRKA_API_KEY",
    "b6caa39c5a6dc520a83ed1624a7bdfdd1935d9fb2bee1d5e2c14dc08ee4ea57ceacca8e9550f5b25ad07b745a612d4b6b5b07bd781baff0908b5891c0beb65c1",
)


def post_json_excel(*, url: str, payload: dict, timeout: int = 180) -> bytes:
    body = json.dumps(payload).encode("utf-8")
    req = urllib.request.Request(
        url,
        data=body,
        headers={"Content-Type": "application/json"},
        method="POST",
    )
    with urllib.request.urlopen(req, timeout=timeout) as resp:
        return resp.read()


merarbejde_regioner = {
    "apiKey": api_key,
    "table": "Særydelser",
    "time": [
        {"y1": "2025", "m1": "02"},
        {"y1": "2024", "m1": "02"},
        {"y1": "2023", "m1": "02"},
        {"y1": "2022", "m1": "02"},
        {"y1": "2021", "m1": "02"},
        {"y1": "2020", "m1": "02"},
        {"y1": "2019", "m1": "02"},
        {"y1": "2018", "m1": "02"},
        {"y1": "2017", "m1": "02"},
        {"y1": "2016", "m1": "02"},
        {"y1": "2015", "m1": "02"},
        {"y1": "2014", "m1": "02"},
    ],
    "control": [],
    "data": ["fuldtid", "sy_l_b", "sy_o_b", "sy_a_b", "sy_d_b", "sy_brut"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "sy": ["028002", "228001"],
                "omr": ["1", "8"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "merarbejde_regioner",
        "subLimit": 5,
        "modelName": "SIRKA",
        "stdstk": True,
        "averageSalary": "1000",
        "timeIncreasing": True,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "særydelser-og-merarbejde"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=merarbejde_regioner, timeout=180)
out_path = out_dir / "merarbejde_regioner.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/særydelser-og-merarbejde/merarbejde_regioner.xlsx

# %%
# Bygger videre på variabler/funktioner fra celle 1: url, api_key, post_json_excel
merarbejde_overenskosmter = {
    "apiKey": api_key,
    "table": "Særydelser",
    "time": [
        {"y1": "2025", "m1": "02"},
    ],
    "control": ["overenskomst"],
    "data": ["fuldtid", "sy_l_b", "sy_o_b", "sy_a_b", "sy_d_b", "sy_brut"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "sy": ["028002", "228001", "228002"],
                "trs": ["272"],
                "omr": ["1", "8"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "merarbejde_overenskosmter",
        "subLimit": 5,
        "modelName": "SIRKA",
        "stdstk": True,
        "averageSalary": "1000",
        "timeIncreasing": True,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

out_dir = Path("Data") / "særydelser-og-merarbejde"
out_dir.mkdir(parents=True, exist_ok=True)

content = post_json_excel(url=url, payload=merarbejde_overenskosmter, timeout=180)
out_path = out_dir / "merarbejde_overenskosmter.xlsx"
out_path.write_bytes(content)

print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/EXCEL/Data/særydelser-og-merarbejde/merarbejde_overenskosmter.xlsx
