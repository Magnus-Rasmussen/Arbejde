# %%
import json
import os
import urllib.request
from pathlib import Path

url = "https://www.krl.dk/sirka/sirkaApi/tableApi"
api_key = os.environ.get(
    "SIRKA_API_KEY",
    "b6caa39c5a6dc520a83ed1624a7bdfdd1935d9fb2bee1d5e2c14dc08ee4ea57ceacca8e9550f5b25ad07b745a612d4b6b5b07bd781baff0908b5891c0beb65c1",
)

def post_json_excel(*, url: str, payload: dict, timeout: int = 180) -> bytes:
    body = json.dumps(payload).encode("utf-8")
    req = urllib.request.Request(
        url,
        data=body,
        headers={"Content-Type": "application/json"},
        method="POST",
    )
    with urllib.request.urlopen(req, timeout=timeout) as resp:
        return resp.read()

payload = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [
        {"y1": "2025", "m1": "12"},
    ],
    "control": ["niv0"],
    "data": ["hoveder"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "omr": ["1", "8"],
                "trs": ["066", "11304"],
                "tra": ["1","2"], "afl": ["0","1"],
                "trl": [
          "R11001",
          "R15034",
          "R4"],
        
                "tre": [
                    "08101",
                    "08205",
                    "08301",
                    "08402",
                    "08403",
                    "08404",
                    "08405",
                    "08407",
                    "08410",
                    "08506",
                    
                ],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Antal ansatte",
        "subLimit": 0,
        "modelName": "SIRKA",
        "timeIncreasing": False,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content = post_json_excel(url=url, payload=payload, timeout=180)

# Save under: Speciallægeloft/speciallægeloft_data
base_dir = Path.cwd()

# Try to locate workspace root that contains 'Speciallægeloft/'
root = None
for candidate in [base_dir, *base_dir.parents][:5]:
    if (candidate / "Speciallægeloft").exists():
        root = candidate
        break

if root is None:
    # Fallback: assume we're already inside Speciallægeloft/
    out_dir = base_dir / "speciallægeloft_data"
else:
    out_dir = root / "Speciallægeloft" / "speciallægeloft_data"

out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / "hospitaler_loft.xlsx"
out_path.write_bytes(content)
print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/Speciallægeloft/speciallægeloft_data/hospitaler_loft.xlsx

# %%
# Nykøbing F (samme kald, ny payload/fil)

payload_nykobing_f = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [
        {"y1": "2025", "m1": "11"},
        {"y1": "2025", "m1": "10"},
        {"y1": "2025", "m1": "09"},
        {"y1": "2025", "m1": "08"},
        {"y1": "2025", "m1": "07"},
        {"y1": "2025", "m1": "06"},
        {"y1": "2025", "m1": "05"},
        {"y1": "2025", "m1": "04"},
        {"y1": "2025", "m1": "03"},
        {"y1": "2025", "m1": "02"},
        {"y1": "2025", "m1": "01"},
        {"y1": "2024", "m1": "12"},
    ],
    "control": [],
    "data": ["hoveder"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "omr": ["1", "8"],
                "trs": ["066", "11304"],
                "tre": [
                    "08506030200303",
                    "085060403",
                    "085060406",
                    "085060407",
                    "085060503",
                    "08506051000204",
                    "08506051000205",
                    "08506060400203",
                    "08506070600304",
                    "0850608",
                ],
                "tra": ["1", "2"],
                "afl": ["0", "1"],
                "trl": [
          "R11001",
          "R15034",
          "R4"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Antal ansatte",
        "subLimit": 0,
        "modelName": "Lokale Løndata",
        "timeIncreasing": True,
        "groupName": "Nykøbing F",
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content_nykobing_f = post_json_excel(url=url, payload=payload_nykobing_f, timeout=180)

# Gem i samme mappe som før (out_dir er lavet i celle 1)
out_path_nykobing_f = out_dir / "Nykøbing_F.xlsx"
out_path_nykobing_f.write_bytes(content_nykobing_f)
print("Wrote:", out_path_nykobing_f.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/Speciallægeloft/speciallægeloft_data/Nykøbing_F.xlsx

# %%
# Thisted (samme kald, ny payload/fil)

payload_thisted = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [
        {"y1": "2025", "m1": "11"},
        {"y1": "2025", "m1": "10"},
        {"y1": "2025", "m1": "09"},
        {"y1": "2025", "m1": "08"},
        {"y1": "2025", "m1": "07"},
        {"y1": "2025", "m1": "06"},
        {"y1": "2025", "m1": "05"},
        {"y1": "2025", "m1": "04"},
        {"y1": "2025", "m1": "03"},
        {"y1": "2025", "m1": "02"},
        {"y1": "2025", "m1": "01"},
        {"y1": "2024", "m1": "12"},
    ],
    "control": [],
    "data": ["hoveder"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "omr": ["1", "8"],
                "trs": ["066", "11304"],
                "tre": [
                    "0810101120020303",
                    "081010114003",
                    "0810101140040303",
                    "0810101140050307",
                    "081010115005",
                    "0810101170020303",
                    "081010119002",
                    "081010119007",
                ],
                "tra": ["1", "2"],
                "afl": ["0", "1"],
                "trl": ["R11001", "R15034", "R4"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Antal ansatte",
        "subLimit": 0,
        "modelName": "Lokale Løndata",
        "timeIncreasing": True,
        "groupName": "Thisted",
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content_thisted = post_json_excel(url=url, payload=payload_thisted, timeout=180)

# Gem i samme mappe som før (out_dir er lavet i celle 1)
out_path_thisted = out_dir / "Thisted.xlsx"
out_path_thisted.write_bytes(content_thisted)
print("Wrote:", out_path_thisted.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/Speciallægeloft/speciallægeloft_data/Thisted.xlsx

# %%
# Steno

payload_Steno = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [
        {"y1": "2025", "m1": "11"},
        {"y1": "2025", "m1": "10"},
        {"y1": "2025", "m1": "09"},
        {"y1": "2025", "m1": "08"},
        {"y1": "2025", "m1": "07"},
        {"y1": "2025", "m1": "06"},
        {"y1": "2025", "m1": "05"},
        {"y1": "2025", "m1": "04"},
        {"y1": "2025", "m1": "03"},
        {"y1": "2025", "m1": "02"},
        {"y1": "2025", "m1": "01"},
        {"y1": "2024", "m1": "12"},
    ],
    "control": ["niv0"],
    "data": ["hoveder"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "omr": ["1", "8"],
                "trs": ["066", "11304"],
                "tre": [
                    "08113",
          "0820561",
          "0830158",
          "08411",
          "08511"
                ],
                "tra": ["1", "2"],
                "afl": ["0", "1"],
                "trl": [
          "R11001",
          "R15034",
          "R4"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Antal ansatte",
        "subLimit": 0,
        "modelName": "Lokale Løndata",
        "timeIncreasing": True,
        
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content_Steno = post_json_excel(url=url, payload=payload_Steno, timeout=180)

# Gem i samme mappe som før (out_dir er lavet i celle 1)
out_path_Steno = out_dir / "Steno.xlsx"
out_path_Steno.write_bytes(content_Steno)
print("Wrote:", out_path_Steno.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/Speciallægeloft/speciallægeloft_data/Steno.xlsx

# %%
# Ålborg + Stenonordjylland

payload_Aalborg_Steno = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [
        {"y1": "2025", "m1": "12"},
       
    ],
    "control": ["niv0"],
    "data": ["hoveder"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "omr": ["1", "8"],
                "trs": ["066", "11304"],
                "tre": [
                    "08113", "08101"
       
                ],
                "tra": ["1", "2"],
                "afl": ["0", "1"],
                "trl": [
          "R11001",
          "R15034",
          "R4"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Antal ansatte",
        "subLimit": 0,
        "modelName": "Lokale Løndata",
        "timeIncreasing": True,
        
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content_Aalborg_Steno = post_json_excel(url=url, payload=payload_Aalborg_Steno, timeout=180)

# Gem i samme mappe som før (out_dir er lavet i celle 1)
out_path_Aalborg_Steno = out_dir / "Aalborg+Steno_Nordjylland.xlsx"
out_path_Aalborg_Steno.write_bytes(content_Aalborg_Steno)
print("Wrote:", out_path_Aalborg_Steno.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/Speciallægeloft/speciallægeloft_data/Aalborg+Steno_Nordjylland.xlsx

# %%
# Sjælland + Steno Sjælland

payload_Sjælland_Steno = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [
        {"y1": "2025", "m1": "12"},
       
    ],
    "control": ["niv0"],
    "data": ["hoveder"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "omr": ["1", "8"],
                "trs": ["066", "11304"],
                "tre": [
                    "08511", "08506"
       
                ],
                "tra": ["1", "2"],
                "afl": ["0", "1"],
                "trl": [
          "R11001",
          "R15034",
          "R4"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Antal ansatte",
        "subLimit": 0,
        "modelName": "Lokale Løndata",
        "timeIncreasing": True,
        
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content_Sjælland_Steno = post_json_excel(url=url, payload=payload_Sjælland_Steno, timeout=180)

# Gem i samme mappe som før (out_dir er lavet i celle 1)
out_path_Sjælland_Steno = out_dir / "Sjælland+Steno_Sjælland.xlsx"
out_path_Sjælland_Steno.write_bytes(content_Sjælland_Steno)
print("Wrote:", out_path_Sjælland_Steno.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/Speciallægeloft/speciallægeloft_data/Sjælland+Steno_Sjælland.xlsx
