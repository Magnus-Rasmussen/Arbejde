# %%
import json
import os
import urllib.request
from pathlib import Path

url = "https://www.krl.dk/sirka/sirkaApi/tableApi"
api_key = os.environ.get(
    "SIRKA_API_KEY",
    "b6caa39c5a6dc520a83ed1624a7bdfdd1935d9fb2bee1d5e2c14dc08ee4ea57ceacca8e9550f5b25ad07b745a612d4b6b5b07bd781baff0908b5891c0beb65c1",
)

def post_json_excel(*, url: str, payload: dict, timeout: int = 180) -> bytes:
    body = json.dumps(payload).encode("utf-8")
    req = urllib.request.Request(
        url,
        data=body,
        headers={"Content-Type": "application/json"},
        method="POST",
    )
    with urllib.request.urlopen(req, timeout=timeout) as resp:
        return resp.read()

# Region Hovedstaden
payload_region_hovedstaden = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [
        {"y1": "2025", "m1": "11"},
        {"y1": "2025", "m1": "10"},
        {"y1": "2025", "m1": "09"},
        {"y1": "2025", "m1": "08"},
        {"y1": "2025", "m1": "07"},
        {"y1": "2025", "m1": "06"},
        {"y1": "2025", "m1": "05"},
        {"y1": "2025", "m1": "04"},
        {"y1": "2025", "m1": "03"},
        {"y1": "2025", "m1": "02"},
        {"y1": "2025", "m1": "01"},
        {"y1": "2024", "m1": "12"},
    ],
    "control": ["niv0"],
    "data": ["hoveder"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "omr": ["1", "8"],
                "trs": ["066", "11304"],
                "tre": ["08408", "08411", "08414"],
                "tra": ["1", "2"],
                "afl": ["0", "1"],
                "trl": ["R11001", "R15034", "R4"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Antal ansatte",
        "subLimit": 0,
        "modelName": "Lokale Løndata",
        "timeIncreasing": True,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content_region_hovedstaden = post_json_excel(
    url=url, payload=payload_region_hovedstaden, timeout=180
 )

# Save under: Speciallægeloft/speciallægeloft_data
base_dir = Path.cwd()

root = None
for candidate in [base_dir, *base_dir.parents][:5]:
    if (candidate / "Speciallægeloft").exists():
        root = candidate
        break

if root is None:
    out_dir = base_dir / "speciallægeloft_data"
else:
    out_dir = root / "Speciallægeloft" / "speciallægeloft_data"

out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / "Region_Hovedstaden.xlsx"
out_path.write_bytes(content_region_hovedstaden)
print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/Speciallægeloft/speciallægeloft_data/Region_Hovedstaden.xlsx

# %%
# Region Midt
payload_region_midt = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [
        {"y1": "2025", "m1": "11"},
        {"y1": "2025", "m1": "10"},
        {"y1": "2025", "m1": "09"},
        {"y1": "2025", "m1": "08"},
        {"y1": "2025", "m1": "07"},
        {"y1": "2025", "m1": "06"},
        {"y1": "2025", "m1": "05"},
        {"y1": "2025", "m1": "04"},
        {"y1": "2025", "m1": "03"},
        {"y1": "2025", "m1": "02"},
        {"y1": "2025", "m1": "01"},
        {"y1": "2024", "m1": "12"},
    ],
    "control": ["niv0"],
    "data": ["hoveder"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "omr": ["1", "8"],
                "trs": ["066", "11304"],
                "tre": ["08201",
          "08202",
          "08203",
          "08204"],
                "tra": ["1", "2"],
                "afl": ["0", "1"],
                "trl": ["R11001", "R15034", "R4"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Antal ansatte",
        "subLimit": 0,
        "modelName": "Lokale Løndata",
        "timeIncreasing": True,

    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content_region_midt = post_json_excel(
    url=url, payload=payload_region_midt, timeout=180
 )

# Save under: Speciallægeloft/speciallægeloft_data
base_dir = Path.cwd()

root = None
for candidate in [base_dir, *base_dir.parents][:5]:
    if (candidate / "Speciallægeloft").exists():
        root = candidate
        break

if root is None:
    out_dir = base_dir / "speciallægeloft_data"
else:
    out_dir = root / "Speciallægeloft" / "speciallægeloft_data"

out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / "Region_Midt.xlsx"
out_path.write_bytes(content_region_midt)
print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/Speciallægeloft/speciallægeloft_data/Region_Midt.xlsx

# %%
# Region Nordjylland
payload_region_nordjylland = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [
        {"y1": "2025", "m1": "11"},
        {"y1": "2025", "m1": "10"},
        {"y1": "2025", "m1": "09"},
        {"y1": "2025", "m1": "08"},
        {"y1": "2025", "m1": "07"},
        {"y1": "2025", "m1": "06"},
        {"y1": "2025", "m1": "05"},
        {"y1": "2025", "m1": "04"},
        {"y1": "2025", "m1": "03"},
        {"y1": "2025", "m1": "02"},
        {"y1": "2025", "m1": "01"},
        {"y1": "2024", "m1": "12"},
    ],
    "control": ["niv0"],
    "data": ["hoveder"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "omr": ["1", "8"],
                "trs": ["066", "11304"],
                "tre": [
                    "0810101140030302",
                    "0810101140040303",
                    "0810101140050307",
                    "0810101150050202",
                    "0810101150050302",
                    "0810101170020303",
                    "0810101190020202",
                    "0810101190020302",
                    "0810101190070202",
                    "08102",
                    "08112",
                    "08113",
                ],
                "tra": ["1", "2"],
                "afl": ["0", "1"],
                 "trl": ["R11001", "R15034", "R4"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Antal ansatte",
        "subLimit": 0,
        "modelName": "Lokale Løndata",
        "timeIncreasing": True,
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content_region_nordjylland = post_json_excel(
    url=url, payload=payload_region_nordjylland, timeout=180
 )

# Save under: Speciallægeloft/speciallægeloft_data
base_dir = Path.cwd()

root = None
for candidate in [base_dir, *base_dir.parents][:5]:
    if (candidate / "Speciallægeloft").exists():
        root = candidate
        break

if root is None:
    out_dir = base_dir / "speciallægeloft_data"
else:
    out_dir = root / "Speciallægeloft" / "speciallægeloft_data"

out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / "Region_Nordjylland.xlsx"
out_path.write_bytes(content_region_nordjylland)
print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/Speciallægeloft/speciallægeloft_data/Region_Nordjylland.xlsx

# %%
# Region Sjælland
payload_region_sjaelland = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [
        {"y1": "2025", "m1": "11"},
        {"y1": "2025", "m1": "10"},
        {"y1": "2025", "m1": "09"},
        {"y1": "2025", "m1": "08"},
        {"y1": "2025", "m1": "07"},
        {"y1": "2025", "m1": "06"},
        {"y1": "2025", "m1": "05"},
        {"y1": "2025", "m1": "04"},
        {"y1": "2025", "m1": "03"},
        {"y1": "2025", "m1": "02"},
        {"y1": "2025", "m1": "01"},
        {"y1": "2024", "m1": "12"},
    ],
    "control": ["niv0"],
    "data": ["hoveder"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "omr": ["1", "8"],
                "trs": ["066", "11304"],
                "tre": [
                    "08503",
                    "08506030200303",
                    "085060403",
                    "085060406",
                    "085060407",
                    "085060503",
                    "08506051000204",
                    "08506051000205",
                    "08506060400203",
                    "08506070600304",
                    "0850608",
                    "08511",
                    "90505",
                ],
                "tra": ["1", "2"],
                "afl": ["0", "1"],
                "trl": ["R11001", "R15034", "R4"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Antal ansatte",
        "subLimit": 0,
        "modelName": "Lokale Løndata",
        "timeIncreasing": True,
        "groupName": "Region Sjælland",
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content_region_sjaelland = post_json_excel(
    url=url, payload=payload_region_sjaelland, timeout=180
 )

# Save under: Speciallægeloft/speciallægeloft_data
base_dir = Path.cwd()

root = None
for candidate in [base_dir, *base_dir.parents][:5]:
    if (candidate / "Speciallægeloft").exists():
        root = candidate
        break

if root is None:
    out_dir = base_dir / "speciallægeloft_data"
else:
    out_dir = root / "Speciallægeloft" / "speciallægeloft_data"

out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / "Region_Sjælland.xlsx"
out_path.write_bytes(content_region_sjaelland)
print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/Speciallægeloft/speciallægeloft_data/Region_Sjælland.xlsx

# %%
# Region Syd
payload_region_syd = {
    "apiKey": api_key,
    "table": "Personale-måned",
    "time": [
        {"y1": "2025", "m1": "11"},
        {"y1": "2025", "m1": "10"},
        {"y1": "2025", "m1": "09"},
        {"y1": "2025", "m1": "08"},
        {"y1": "2025", "m1": "07"},
        {"y1": "2025", "m1": "06"},
        {"y1": "2025", "m1": "05"},
        {"y1": "2025", "m1": "04"},
        {"y1": "2025", "m1": "03"},
        {"y1": "2025", "m1": "02"},
        {"y1": "2025", "m1": "01"},
        {"y1": "2024", "m1": "12"},
    ],
    "control": ["niv0"],
    "data": ["hoveder"],
    "selection": [
        {
            "name": "Udvalgte population",
            "filters": {
                "omr": ["1", "8"],
                "trs": ["066", "11304"],
                "tre": ["08302", "08303", "08304"],
                "tra": ["1", "2"],
                "afl": ["0", "1"],
                "trl": ["R11001", "R15034", "R4"],
            },
        }
    ],
    "options": {
        "totals": True,
        "outputFormat": "excel",
        "actions": [],
        "tableName": "Antal ansatte",
        "subLimit": 0,
        "modelName": "Lokale Løndata",
        "timeIncreasing": False,
        "groupName": "Region Syd",
    },
    "dimension": {
        "viewportHeight": 812,
        "viewportWidth": 1440,
        "xsMaxWidth": 768,
        "smMaxWidth": 992,
        "mdMaxWidth": 1200,
        "CONSTANTS": {"XS": 0, "SM": 1, "MD": 2, "LG": 3, "MAIL": 4},
    },
}

content_region_syd = post_json_excel(url=url, payload=payload_region_syd, timeout=180)

# Save under: Speciallægeloft/speciallægeloft_data
base_dir = Path.cwd()

root = None
for candidate in [base_dir, *base_dir.parents][:5]:
    if (candidate / "Speciallægeloft").exists():
        root = candidate
        break

if root is None:
    out_dir = base_dir / "speciallægeloft_data"
else:
    out_dir = root / "Speciallægeloft" / "speciallægeloft_data"

out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / "Region_Syd.xlsx"
out_path.write_bytes(content_region_syd)
print("Wrote:", out_path.resolve())
# Out:
# Wrote: /Users/magnusrasmussen/Desktop/Arbejde/Speciallægeloft/speciallægeloft_data/Region_Syd.xlsx
